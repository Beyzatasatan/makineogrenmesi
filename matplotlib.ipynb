# %% [raw]
# line plot

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[10,20,25,30]
plt.plot(x,y)
plt.title("Basit çizgi grafiği")
plt.xlabel("x ekseni")
plt.ylabel("y ekseni")
plt.grid()
plt.show()

# %% [raw]
# bar plots

# %%
import matplotlib.pyplot as plt
kategori=["a","b","c","d"]
values=[3,7,5,12]
plt.bar(kategori,values ,color="#f542ef")
plt.title("Basit çubuk grafiği",color="#42f5ec",fontsize=50)
plt.xlabel("x ekseni")
plt.ylabel("y ekseni")
plt.grid()
plt.show()

# %% [raw]
# Horizontal bar chart

# %%
import matplotlib.pyplot as plt
kategori=["a","b","c","d"]
values=[3,7,5,12]
plt.barh(kategori,values ,color="#f542ef")
plt.title("Basit çubuk grafiği",color="#42f5ec",fontsize=50)
plt.xlabel("x ekseni")
plt.ylabel("y ekseni")
plt.grid()
plt.show()

# %%
import numpy as np
kategori=["a","b","c","d"]
values1=[3,7,5,12]
values2=[4,6,8,10]
values3=[9,10,11,13]
x=np.arange(len(kategori))
print(x)
plt.bar(x-0.2,values1,width=0.2,label="set1")
plt.bar(x ,values2,width=0.2,label="set2")
plt.bar(x+0.2 ,values3,width=0.2,label="set3")
plt.xticks(x,kategori)
plt.title("ggggggggggg")
plt.xlabel("kategori")
plt.ylabel("degerler")
plt.legend()
plt.show()
# Out:
# [0 1 2 3]

# %%
plt.bar(kategori,values1,label="set1")
plt.bar(kategori,values2,bottom=values1,label="set2")

plt.title("yığılmış çubuk grafiği")
plt.xlabel("kategori")
plt.ylabel("degerler")
plt.legend()
plt.show()

# %% [raw]
# pasta grafiği

# %%
import matplotlib.pyplot as plt
a=["elma","muz","kiraz","portakal"]
sizes=[15,30,45,10]
plt.pie(sizes,labels=a,autopct='%1.1f%%')
plt.title("meyve dağıtılımı")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data=np.random.randn(1000)
plt.hist(data,bins=10,histtype="bar")
plt.title("histogram")
plt.ylabel("frekans")
plt.xlabel("degerler")

plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,25,30,35]
plt.scatter(x,y, marker="*",color="red",linewidth=5)
plt.title("dağılım")
plt.ylabel("y değeri")
plt.xlabel("x degeri")

plt.show()

# %%
colors=[10,20,30,40,50]
sizes=[100,200,300,400,500]
plt.scatter(x,y,c=colors,s=sizes,alpha=0.5,cmap="viridis")
plt.colorbar()
plt.title("özelleştirilmiş dağılım")
plt.ylabel("y değeri")
plt.xlabel("x degeri")

plt.show()

# %%
plt.figure(figsize=(10,6),dpi=100)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
fig,axs=plt.subplots(2,2)
fig.suptitle("dört şekil orta başlık")
axs[0,0].plot(x,y)
axs[0,0].set_title("grafik1")
axs[0,1].bar(kategori,values)
axs[0,1].set_title("grafik2")
axs[1,0].hist(data)
axs[1,0].set_title("grafik3")
axs[1,1].pie(sizes,labels=sizes,autopct='%1.1f%%')
axs[1,1].set_title("grafik4")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
fig,(axs1,axs2)=plt.subplots(1,2)
fig.suptitle("iki şekil orta başlık")
axs1.plot(x,y)
axs1.set_title("grafik1")
axs2.bar(kategori,values)
axs2.set_title("grafik2")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
fig,(axs1,axs2)=plt.subplots(2,1,sharex=True)
fig.suptitle("iki şekil orta başlık")
axs1.plot(x,y)
axs1.set_title("grafik1")
axs2.bar(kategori,values)
axs2.set_title("grafik2")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df1=pd.read_csv("C:\\Users\\LENOVO\\Documents\\makineogrenmesi\\car_sales.csv")
df1['Price']=df1['Price'].str.replace('$',' ').str.replace(',','').astype(float).astype(int)

df1["sale date"]=pd.date_range(start="1-1-2024",periods=len(df1))
df1["total sale"]=df1["Price"].cumsum()
print(df1)
plt.subplot(2,1,1)
plt.plot(df1["Odometer (KM)"],df1["sale date"])
plt.subplot(2,1,2)
plt.bar(df1["Make"],df1["Price"])
plt.show()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  sale date  total sale
# 0  Toyota  White         150043      4   4000 2024-01-01        4000
# 1   Honda    Red          87899      4   5000 2024-01-02        9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03       16000
# 3     BMW  Black          11179      5  22000 2024-01-04       38000
# 4  Nissan  White         213095      4   3500 2024-01-05       41500
# 5  Toyota  Green          99213      4   4500 2024-01-06       46000
# 6   Honda   Blue          45698      4   7500 2024-01-07       53500
# 7   Honda   Blue          54738      4   7000 2024-01-08       60500
# 8  Toyota  White          60000      4   6250 2024-01-09       66750
# 9  Nissan  White          31600      4   9700 2024-01-10       76450

# %%
import pandas as pd
df1=pd.read_csv("C:\\Users\\LENOVO\\Documents\\makineogrenmesi\\car_sales.csv")
df1
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df1.plot(x="Make",y="Price",kind="bar")
# Out:
# <Axes: xlabel='Make'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df1=pd.read_csv("C:\\Users\\LENOVO\\Documents\\makineogrenmesi\\car_sales.csv")
df1['Price']=df1['Price'].str.replace('$',' ').str.replace(',','').astype(float).astype(int)

df1["sale date"]=pd.date_range(start="1-1-2024",periods=len(df1))
df1["total sale"]=df1["Price"].cumsum()
print(df1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  sale date  total sale
# 0  Toyota  White         150043      4   4000 2024-01-01        4000
# 1   Honda    Red          87899      4   5000 2024-01-02        9000
# 2  Toyota   Blue          32549      3   7000 2024-01-03       16000
# 3     BMW  Black          11179      5  22000 2024-01-04       38000
# 4  Nissan  White         213095      4   3500 2024-01-05       41500
# 5  Toyota  Green          99213      4   4500 2024-01-06       46000
# 6   Honda   Blue          45698      4   7500 2024-01-07       53500
# 7   Honda   Blue          54738      4   7000 2024-01-08       60500
# 8  Toyota  White          60000      4   6250 2024-01-09       66750
# 9  Nissan  White          31600      4   9700 2024-01-10       76450
